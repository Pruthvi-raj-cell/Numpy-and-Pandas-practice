# %%
import pandas as pd
import numpy as np
from jupyter_core.migrate import regex

# %%
nums = pd.Series([3,5,3,6])

# %%
nums
# Out:
# 0    3
# 1    5
# 2    3
# 3    6
# dtype: int64

# %%
df = pd.read_csv(r"employees_100.csv")

# %%
df
# Out:
#     employee_id            name    department       city   age salary  \
# 0           184    Swati Kapoor  Data Science    Kolkata  38.0  70719
# 1           154  Kavya Malhotra   engineering     Mumbai   NaN  77058
# 2           171    Manish Desai  Data Science  Hyderabad  23.0  69911
# 3           146        Neha Das   Engineering       Pune  28.0  69993
# 4           145       Isha Nair  Data Science        NaN  32.0  88216
# ..          ...             ...           ...        ...   ...    ...
# 95          161     Nikhil Nair     MARKETING    Chennai  22.0  55740
# 96          172      Neha Desai            HR    Chennai  22.0  52250
# 97          115      Neha Reddy     Marketing    Chennai  43.0    NaN
# 98          193     Priya Nayak            HR        NaN  23.0  56821
# 99          152     Kavya Joshi     Marketing      Delhi  44.0  69499
#
#     experience  performance_score  projects_completed joining_date
# ...

# %%
df.head(

)
# Out:
#    employee_id            name    department       city   age salary  \
# 0          184    Swati Kapoor  Data Science    Kolkata  38.0  70719
# 1          154  Kavya Malhotra   engineering     Mumbai   NaN  77058
# 2          171    Manish Desai  Data Science  Hyderabad  23.0  69911
# 3          146        Neha Das   Engineering       Pune  28.0  69993
# 4          145       Isha Nair  Data Science        NaN  32.0  88216
#
#    experience  performance_score  projects_completed joining_date
# 0           5                  5                   6   2021-07-02
# 1           1                  8                   8   2024-02-05
# 2           0                  6                  18   2019-04-24
# 3           3                  8                   1   2022-12-13
# 4           8                  8                  14   2019-11-25

# %%
df.tail()
# Out:
#     employee_id         name department     city   age salary  experience  \
# 95          161  Nikhil Nair  MARKETING  Chennai  22.0  55740           0
# 96          172   Neha Desai         HR  Chennai  22.0  52250           0
# 97          115   Neha Reddy  Marketing  Chennai  43.0    NaN          12
# 98          193  Priya Nayak         HR      NaN  23.0  56821           3
# 99          152  Kavya Joshi  Marketing    Delhi  44.0  69499          10
#
#     performance_score  projects_completed joining_date
# 95                  5                  22   2020-04-22
# 96                  5                   7   2020-11-14
# 97                  4                  10   2019-06-06
# 98                  9                  16   2019-08-07
# 99                  7                   4   2022-03-25

# %%
df.sample()
# Out:
#     employee_id         name   department     city   age salary  experience  \
# 25          116  Rohan Verma  Engineering  Chennai  23.0  62693           0
#
#     performance_score  projects_completed joining_date
# 25                  4                   8   2018-08-17

# %%
df.info
# Out:
# <bound method DataFrame.info of     employee_id            name    department       city   age salary  \
# 0           184    Swati Kapoor  Data Science    Kolkata  38.0  70719
# 1           154  Kavya Malhotra   engineering     Mumbai   NaN  77058
# 2           171    Manish Desai  Data Science  Hyderabad  23.0  69911
# 3           146        Neha Das   Engineering       Pune  28.0  69993
# 4           145       Isha Nair  Data Science        NaN  32.0  88216
# ..          ...             ...           ...        ...   ...    ...
# 95          161     Nikhil Nair     MARKETING    Chennai  22.0  55740
# 96          172      Neha Desai            HR    Chennai  22.0  52250
# 97          115      Neha Reddy     Marketing    Chennai  43.0    NaN
# 98          193     Priya Nayak            HR        NaN  23.0  56821
# 99          152     Kavya Joshi     Marketing      Delhi  44.0  69499
#
#     experience  performance_score  projects_completed joining_date
# ...

# %%
df.describe()
# Out:
#        employee_id        age  experience  performance_score  \
# count   100.000000  94.000000  100.000000           100.0000
# mean    148.740000  30.861702    4.830000             5.7500
# std      27.420637   6.483397    3.755279             1.7019
# min     101.000000  22.000000    0.000000             2.0000
# 25%     125.750000  25.250000    2.000000             5.0000
# 50%     149.500000  31.000000    4.500000             6.0000
# 75%     171.250000  35.750000    8.000000             7.0000
# max     196.000000  45.000000   17.000000            10.0000
#
#        projects_completed
# count          100.000000
# mean             9.970000
# std              5.332301
# min              0.000000
# 25%              6.000000
# 50%              9.500000
# 75%             13.250000
# max             24.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   employee_id         100 non-null    int64
#  1   name                100 non-null    str
#  2   department          92 non-null     str
#  3   city                90 non-null     str
#  4   age                 94 non-null     float64
#  5   salary              92 non-null     str
#  6   experience          100 non-null    int64
#  7   performance_score   100 non-null    int64
#  8   projects_completed  100 non-null    int64
#  9   joining_date        100 non-null    str
# dtypes: float64(1), int64(4), str(5)
# memory usage: 7.9 KB

# %%
#understand ur data first then work  on it

# %%
df['salary']
# Out:
# 0     70719
# 1     77058
# 2     69911
# 3     69993
# 4     88216
#       ...
# 95    55740
# 96    52250
# 97      NaN
# 98    56821
# 99    69499
# Name: salary, Length: 100, dtype: str

# %%
df[['salary', 'name']] # have to use [[]]
# Out:
#    salary            name
# 0   70719    Swati Kapoor
# 1   77058  Kavya Malhotra
# 2   69911    Manish Desai
# 3   69993        Neha Das
# 4   88216       Isha Nair
# ..    ...             ...
# 95  55740     Nikhil Nair
# 96  52250      Neha Desai
# 97    NaN      Neha Reddy
# 98  56821     Priya Nayak
# 99  69499     Kavya Joshi
#
# [100 rows x 2 columns]

# %%
df[df['name'] == "Swati Kapoor"]
# Out:
#    employee_id          name    department     city   age salary  experience  \
# 0          184  Swati Kapoor  Data Science  Kolkata  38.0  70719           5
#
#    performance_score  projects_completed joining_date
# 0                  5                   6   2021-07-02

# %%
df.iloc[0]
# Out:
# employee_id                    184
# name                  Swati Kapoor
# department            Data Science
# city                       Kolkata
# age                           38.0
# salary                       70719
# experience                       5
# performance_score                5
# projects_completed               6
# joining_date            2021-07-02
# Name: 0, dtype: object

# %%
df.isnull().sum()
# Out:
# employee_id            0
# name                   0
# department             8
# city                  10
# age                    6
# salary                 8
# experience             0
# performance_score      0
# projects_completed     0
# joining_date           0
# dtype: int64

# %%
df[df['age'] > 40]
# Out:
#     employee_id          name    department       city   age salary  \
# 18          113     Ritu Nair       Finance        NaN  41.0  74778
# 55          179     Arjun Das       Finance        NaN  43.0    NaN
# 61          164   Sneha Gupta           NaN      Delhi  42.0  63209
# 62          155    Sanjay Das           NaN  Bangalore  45.0  74505
# 76          176  Shreya Menon       Finance        NaN  41.0  80597
# 80          164   Sneha Gupta           NaN      Delhi  42.0  63209
# 88          124  Deepak Verma  Data Science  Hyderabad  41.0  86380
# 97          115    Neha Reddy     Marketing    Chennai  43.0    NaN
# 99          152   Kavya Joshi     Marketing      Delhi  44.0  69499
#
#     experience  performance_score  projects_completed joining_date
# 18          10                  7                   5   2018-02-13
# 55          10                  7                  11   2024-08-25
# 61          11                  3                   8   2021-08-07
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   employee_id         100 non-null    int64
#  1   name                100 non-null    str
#  2   department          92 non-null     str
#  3   city                90 non-null     str
#  4   age                 94 non-null     float64
#  5   salary              92 non-null     str
#  6   experience          100 non-null    int64
#  7   performance_score   100 non-null    int64
#  8   projects_completed  100 non-null    int64
#  9   joining_date        100 non-null    str
# dtypes: float64(1), int64(4), str(5)
# memory usage: 7.9 KB

# %%
df2 = df.dropna()

# %%
df2.isnull().sum()
# Out:
# employee_id           0
# name                  0
# department            0
# city                  0
# age                   0
# salary                0
# experience            0
# performance_score     0
# projects_completed    0
# joining_date          0
# dtype: int64

# %%
# removed the null values but this isnt the right way

# %%
df.isnull().sum()
# Out:
# employee_id            0
# name                   0
# department             8
# city                  10
# age                    6
# salary                 8
# experience             0
# performance_score      0
# projects_completed     0
# joining_date           0
# dtype: int64

# %%
df = df.dropna(subset = ['city'])

# %%
df.isnull().sum()
# Out:
# employee_id           0
# name                  0
# department            7
# city                  0
# age                   6
# salary                7
# experience            0
# performance_score     0
# projects_completed    0
# joining_date          0
# dtype: int64

# %%
df.shape
# Out:
# (90, 10)

# %%
df['age'] = df['age'].fillna(df['age'].mean())

# %%
df.isnull().sum(
)
# Out:
# employee_id           0
# name                  0
# department            7
# city                  0
# age                   0
# salary                7
# experience            0
# performance_score     0
# projects_completed    0
# joining_date          0
# dtype: int64

# %%
# better way to fill those null values we used mean of all the ages in age col to fill the null values in age

# %%
df['department'].value_counts()
# Out:
# department
# HR                                                                                                                                                                                                                                                                                                    16
# Marketing                                                                                                                                                                                                                                                                                             16
# Engineering                                                                                                                                                                                                                                                                                           14
# ...

# %%
df['department'] = df['department'].str.strip().str.title()
df['department'] = df['department'].replace({'Hr': 'HR'})
df['department'] = df['department'].fillna(df['department'].mode()[0])

# %%
df.isnull().sum()
# Out:
# employee_id           0
# name                  0
# department            0
# city                  0
# age                   0
# salary                0
# experience            0
# performance_score     0
# projects_completed    0
# joining_date          0
# dtype: int64

# %%
# used median to fill the null value in department

# %%
#df['salary'] = df['salary'].astype(int) ######################################see thishsssssss

df['salary'] = pd.to_numeric(df['salary'] , errors="coerce")

# %%
df.isnull().sum()
# Out:
# employee_id           0
# name                  0
# department            0
# city                  0
# age                   0
# salary                0
# experience            0
# performance_score     0
# projects_completed    0
# joining_date          0
# dtype: int64

# %%
df['salary'] = df['salary'].fillna(df['salary'].median())

# %%
df.isnull().sum()
# Out:
# employee_id           0
# name                  0
# department            0
# city                  0
# age                   0
# salary                0
# experience            0
# performance_score     0
# projects_completed    0
# joining_date          0
# dtype: int64

# %%
###### now the data is without null value but this isnt clean yet because we can have dul values in this date set

# %%
df.sample()
# Out:
#     employee_id        name department       city   age   salary  experience  \
# 62          155  Sanjay Das         HR  Bangalore  45.0  74505.0          17
#
#     performance_score  projects_completed joining_date
# 62                  6                  10   2022-06-22

# %%
df.head()
# Out:
#    employee_id            name    department       city        age   salary  \
# 0          184    Swati Kapoor  Data Science    Kolkata  38.000000  70719.0
# 1          154  Kavya Malhotra   Engineering     Mumbai  30.761905  77058.0
# 2          171    Manish Desai  Data Science  Hyderabad  23.000000  69911.0
# 3          146        Neha Das   Engineering       Pune  28.000000  69993.0
# 5          140     Rahul Gupta         Sales  Hyderabad  23.000000  52404.0
#
#    experience  performance_score  projects_completed joining_date
# 0           5                  5                   6   2021-07-02
# 1           1                  8                   8   2024-02-05
# 2           0                  6                  18   2019-04-24
# 3           3                  8                   1   2022-12-13
# 5           0                  9                  13   2018-12-27

# %%
df.tail()
# Out:
#     employee_id         name    department     city   age   salary  \
# 94          121   Ashok Shah  Data Science     Pune  31.0  75498.0
# 95          161  Nikhil Nair     Marketing  Chennai  22.0  55740.0
# 96          172   Neha Desai            HR  Chennai  22.0  52250.0
# 97          115   Neha Reddy     Marketing  Chennai  43.0  62310.0
# 99          152  Kavya Joshi     Marketing    Delhi  44.0  69499.0
#
#     experience  performance_score  projects_completed joining_date
# 94           4                  7                   7   2024-12-05
# 95           0                  5                  22   2020-04-22
# 96           0                  5                   7   2020-11-14
# 97          12                  4                  10   2019-06-06
# 99          10                  7                   4   2022-03-25
